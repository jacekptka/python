# %% [markdown]
# # Pandas
#
# [Pandas](http://pandas.pydata.org/) jest biblioteką przeznaczoną do analizy danych.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Series
#
# Seria to struktura jednowymiarowa. Każdy element może mieć przypisaną wartość indeksu. Można je tworzyć z innych struktur danych.

# %%
pd.Series(np.random.randn(5))
# Out:
# 0    0.284835
# 1   -1.220032
# 2    0.968104
# 3    0.145083
# 4    0.827630
# dtype: float64

# %%
pd.Series(np.random.randn(5), index=['a', 'b', 'c', 'd', 'e'])
# Out:
# a    0.902152
# b    0.784854
# c   -1.795354
# d   -1.136390
# e    0.682574
# dtype: float64

# %%
pd.Series({'a' : 0., 'b' : 1., 'c' : 2.})
# Out:
# a    0.0
# b    1.0
# c    2.0
# dtype: float64

# %%
s = pd.Series(np.random.randn(5), index=list('abcde'))

# %%
# pobieranie danych

print('s[1] = \n{}'.format(s[1]))
print('s[2:] = \n{}'.format(s[2:]))
print('s[1:-2] = \n{}'.format(s[1:-2]))
# Out:
# s[1] =
# -0.6896715685408826
# s[2:] =
# c   -0.530914
# d    0.667772
# e   -0.528693
# dtype: float64
# s[1:-2] =
# b   -0.689672
# c   -0.530914
# dtype: float64

# %%
# pobieranie danych z wykorzystaniem indeksu

print('s["b"] = \n{}'.format(s['b']))
print('s["c":] = \n{}'.format(s['c':]))
print('s["b":"c"] = \n{}'.format(s['b':'c']))
# Out:
# s["b"] =
# -0.6896715685408826
# s["c":] =
# c   -0.530914
# d    0.667772
# e   -0.528693
# dtype: float64
# s["b":"c"] =
# b   -0.689672
# c   -0.530914
# dtype: float64

# %%
# na seriach można wykonywać operacje

print('s*5 = \n{}'.format(s*5))
print('s**3 = \n{}'.format(s**3))
print('s*s = \n{}'.format(s*s))
print('s+s = \n{}'.format(s+s))
# Out:
# s*5 =
# a    0.411325
# b   -3.448358
# c   -2.654571
# d    3.338858
# e   -2.643465
# dtype: float64
# s**3 =
# a    0.000557
# b   -0.328040
# c   -0.149649
# d    0.297772
# e   -0.147778
# dtype: float64
# s*s =
# a    0.006768
# b    0.475647
# c    0.281870
# d    0.445919
# e    0.279516
# dtype: float64
# s+s =
# a    0.164530
# b   -1.379343
# c   -1.061828
# d    1.335543
# e   -1.057386
# dtype: float64

# %%
# oraz je rysować
# %matplotlib inline

s.plot()

# %% [markdown]
# ## DataFrame
#
# DataFrame jest obiektem dwuwymiarowym, każda kolumna odpowiada serii. Wszystkie kolumny mają wspólny indeks w wierszach.

# %%
df = pd.DataFrame(np.random.randn(10,4), index=pd.date_range('20181115', periods=10), columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2018-11-15 -1.088266  0.077561 -0.158033 -0.572005
# 2018-11-16  0.444033  2.329084  0.192314  0.454020
# 2018-11-17 -0.325505 -1.468963  1.134555  1.783722
# 2018-11-18 -0.790104 -0.837978 -0.340629  2.757331
# 2018-11-19  2.211547 -1.031103  0.961524 -0.449906
# 2018-11-20 -0.916594  0.817857  1.704408  0.754580
# 2018-11-21  1.795535  2.057391  0.640289 -0.212212
# 2018-11-22 -0.412105 -0.858991  0.126454 -1.929453
# 2018-11-23  1.096568  0.229744  1.275525 -1.174126
# 2018-11-24  0.067544  0.494046  1.003044 -0.252660

# %%
# obiekty mogą być zapisywane do plików i wczytywane z plików csv, Excel, itp. oraz innych źródeł danych (SQL)
df.to_csv('sample.csv')
dataframe = pd.read_csv('sample.csv', index_col=0)
dataframe
# Out:
#                    A         B         C         D
# 2018-11-15 -1.088266  0.077561 -0.158033 -0.572005
# 2018-11-16  0.444033  2.329084  0.192314  0.454020
# 2018-11-17 -0.325505 -1.468963  1.134555  1.783722
# 2018-11-18 -0.790104 -0.837978 -0.340629  2.757331
# 2018-11-19  2.211547 -1.031103  0.961524 -0.449906
# 2018-11-20 -0.916594  0.817857  1.704408  0.754580
# 2018-11-21  1.795535  2.057391  0.640289 -0.212212
# 2018-11-22 -0.412105 -0.858991  0.126454 -1.929453
# 2018-11-23  1.096568  0.229744  1.275525 -1.174126
# 2018-11-24  0.067544  0.494046  1.003044 -0.252660

# %%
# podejrzenie początku i końca tabeli

df.head()
# Out:
#                    A         B         C         D
# 2018-11-15 -1.088266  0.077561 -0.158033 -0.572005
# 2018-11-16  0.444033  2.329084  0.192314  0.454020
# 2018-11-17 -0.325505 -1.468963  1.134555  1.783722
# 2018-11-18 -0.790104 -0.837978 -0.340629  2.757331
# 2018-11-19  2.211547 -1.031103  0.961524 -0.449906

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2018-11-22 -0.412105 -0.858991  0.126454 -1.929453
# 2018-11-23  1.096568  0.229744  1.275525 -1.174126
# 2018-11-24  0.067544  0.494046  1.003044 -0.252660

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.index
# Out:
# DatetimeIndex(['2018-11-15', '2018-11-16', '2018-11-17', '2018-11-18',
#                '2018-11-19', '2018-11-20', '2018-11-21', '2018-11-22',
#                '2018-11-23', '2018-11-24'],
#               dtype='datetime64[ns]', freq='D')

# %%
# wybrana kolumna

df['A']
# Out:
# 2018-11-15   -1.088266
# 2018-11-16    0.444033
# 2018-11-17   -0.325505
# 2018-11-18   -0.790104
# 2018-11-19    2.211547
# 2018-11-20   -0.916594
# 2018-11-21    1.795535
# 2018-11-22   -0.412105
# 2018-11-23    1.096568
# 2018-11-24    0.067544
# Freq: D, Name: A, dtype: float64

# %%
# filtrowanie wyników

df[df.B > 0.0]
# Out:
#                    A         B         C         D
# 2018-11-15 -1.088266  0.077561 -0.158033 -0.572005
# 2018-11-16  0.444033  2.329084  0.192314  0.454020
# 2018-11-20 -0.916594  0.817857  1.704408  0.754580
# 2018-11-21  1.795535  2.057391  0.640289 -0.212212
# 2018-11-23  1.096568  0.229744  1.275525 -1.174126
# 2018-11-24  0.067544  0.494046  1.003044 -0.252660

# %%
# sprawdzenie warunku w serii

df.B > 0.0
# Out:
# 2018-11-15     True
# 2018-11-16     True
# 2018-11-17    False
# 2018-11-18    False
# 2018-11-19    False
# 2018-11-20     True
# 2018-11-21     True
# 2018-11-22    False
# 2018-11-23     True
# 2018-11-24     True
# Freq: D, Name: B, dtype: bool

# %%
# operacje na danych - pobieranie i zmiana

print("at")
print(df.at[df.index[0],'A'])
df.at[df.index[0],'A'] = 2.0
print(df.at[df.index[0],'A'])
print("iat")
print(df.iat[0,0])
df.iat[0,0] = np.random.rand()
print(df.iat[0,0])
# Out:
# at
# -1.0882664398
# 2.0
# iat
# 2.0
# 0.515823238637

# %%
# sortowanie po indeksach
df.sort_index(ascending=False)
# Out:
#                    A         B         C         D
# 2018-11-24  0.067544  0.494046  1.003044 -0.252660
# 2018-11-23  1.096568  0.229744  1.275525 -1.174126
# 2018-11-22 -0.412105 -0.858991  0.126454 -1.929453
# 2018-11-21  1.795535  2.057391  0.640289 -0.212212
# 2018-11-20 -0.916594  0.817857  1.704408  0.754580
# 2018-11-19  2.211547 -1.031103  0.961524 -0.449906
# 2018-11-18 -0.790104 -0.837978 -0.340629  2.757331
# 2018-11-17 -0.325505 -1.468963  1.134555  1.783722
# 2018-11-16  0.444033  2.329084  0.192314  0.454020
# 2018-11-15  0.515823  0.077561 -0.158033 -0.572005

# %%
# sortowanie po kolumnach
df.sort_index(axis=1,ascending=False)
# Out:
#                    D         C         B         A
# 2018-11-15 -0.572005 -0.158033  0.077561  0.515823
# 2018-11-16  0.454020  0.192314  2.329084  0.444033
# 2018-11-17  1.783722  1.134555 -1.468963 -0.325505
# 2018-11-18  2.757331 -0.340629 -0.837978 -0.790104
# 2018-11-19 -0.449906  0.961524 -1.031103  2.211547
# 2018-11-20  0.754580  1.704408  0.817857 -0.916594
# 2018-11-21 -0.212212  0.640289  2.057391  1.795535
# 2018-11-22 -1.929453  0.126454 -0.858991 -0.412105
# 2018-11-23 -1.174126  1.275525  0.229744  1.096568
# 2018-11-24 -0.252660  1.003044  0.494046  0.067544

# %%
# sortowanie po wartościach
df.sort_values('A')
# Out:
#                    A         B         C         D
# 2018-11-20 -0.916594  0.817857  1.704408  0.754580
# 2018-11-18 -0.790104 -0.837978 -0.340629  2.757331
# 2018-11-22 -0.412105 -0.858991  0.126454 -1.929453
# 2018-11-17 -0.325505 -1.468963  1.134555  1.783722
# 2018-11-24  0.067544  0.494046  1.003044 -0.252660
# 2018-11-16  0.444033  2.329084  0.192314  0.454020
# 2018-11-15  0.515823  0.077561 -0.158033 -0.572005
# 2018-11-23  1.096568  0.229744  1.275525 -1.174126
# 2018-11-21  1.795535  2.057391  0.640289 -0.212212
# 2018-11-19  2.211547 -1.031103  0.961524 -0.449906

# %%
# usuwanie kolumny
df.drop(columns=['D'])
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-33128c85e8c0> in <module>()
#       1 # usuwanie kolumny
# ----> 2 df.drop(columns=['Z'])
#       3 df
#
# TypeError: drop() got an unexpected keyword argument 'columns'

# %%
# dodawanie kolumny
df['Z'] = np.random.randn(10,1)
df
# Out:
#                    A         B         C         D         Z
# 2018-11-15  0.515823  0.077561 -0.158033 -0.572005  1.500157
# 2018-11-16  0.444033  2.329084  0.192314  0.454020 -1.065538
# 2018-11-17 -0.325505 -1.468963  1.134555  1.783722 -0.116841
# 2018-11-18 -0.790104 -0.837978 -0.340629  2.757331 -0.866775
# 2018-11-19  2.211547 -1.031103  0.961524 -0.449906  0.062056
# 2018-11-20 -0.916594  0.817857  1.704408  0.754580 -0.875199
# 2018-11-21  1.795535  2.057391  0.640289 -0.212212 -0.646072
# 2018-11-22 -0.412105 -0.858991  0.126454 -1.929453 -0.290766
# 2018-11-23  1.096568  0.229744  1.275525 -1.174126  0.036696
# 2018-11-24  0.067544  0.494046  1.003044 -0.252660  1.193120

# %%
# dodawanie kolumny oraz wiersza bez określonych wartości
df['X'] = np.NaN
df = df.append(pd.DataFrame(np.NaN, index=pd.date_range('20181201', periods=1), columns=df.columns))
df
# Out:
#                    A         B         C         D         Z   X
# 2018-11-15  0.515823  0.077561 -0.158033 -0.572005  1.500157 NaN
# 2018-11-16  0.444033  2.329084  0.192314  0.454020 -1.065538 NaN
# 2018-11-17 -0.325505 -1.468963  1.134555  1.783722 -0.116841 NaN
# 2018-11-18 -0.790104 -0.837978 -0.340629  2.757331 -0.866775 NaN
# 2018-11-19  2.211547 -1.031103  0.961524 -0.449906  0.062056 NaN
# 2018-11-20 -0.916594  0.817857  1.704408  0.754580 -0.875199 NaN
# 2018-11-21  1.795535  2.057391  0.640289 -0.212212 -0.646072 NaN
# 2018-11-22 -0.412105 -0.858991  0.126454 -1.929453 -0.290766 NaN
# 2018-11-23  1.096568  0.229744  1.275525 -1.174126  0.036696 NaN
# 2018-11-24  0.067544  0.494046  1.003044 -0.252660  1.193120 NaN
# 2018-12-01       NaN       NaN       NaN       NaN       NaN NaN

# %%
# usuwanie wierszy z nieokreślonymi wartościami
df.dropna(how='any')
# Out:
# Empty DataFrame
# Columns: [A, B, C, D, Z, X]
# Index: []

# %%
df.dropna(how='all')
# Out:
#                    A         B         C         D         Z   X
# 2018-11-15  0.515823  0.077561 -0.158033 -0.572005  1.500157 NaN
# 2018-11-16  0.444033  2.329084  0.192314  0.454020 -1.065538 NaN
# 2018-11-17 -0.325505 -1.468963  1.134555  1.783722 -0.116841 NaN
# 2018-11-18 -0.790104 -0.837978 -0.340629  2.757331 -0.866775 NaN
# 2018-11-19  2.211547 -1.031103  0.961524 -0.449906  0.062056 NaN
# 2018-11-20 -0.916594  0.817857  1.704408  0.754580 -0.875199 NaN
# 2018-11-21  1.795535  2.057391  0.640289 -0.212212 -0.646072 NaN
# 2018-11-22 -0.412105 -0.858991  0.126454 -1.929453 -0.290766 NaN
# 2018-11-23  1.096568  0.229744  1.275525 -1.174126  0.036696 NaN
# 2018-11-24  0.067544  0.494046  1.003044 -0.252660  1.193120 NaN

# %%
# uzupełnianie wartości NaN
df.fillna(-10.0)
# Out:
#                     A          B          C          D          Z     X
# 2018-11-15   0.515823   0.077561  -0.158033  -0.572005   1.500157 -10.0
# 2018-11-16   0.444033   2.329084   0.192314   0.454020  -1.065538 -10.0
# 2018-11-17  -0.325505  -1.468963   1.134555   1.783722  -0.116841 -10.0
# 2018-11-18  -0.790104  -0.837978  -0.340629   2.757331  -0.866775 -10.0
# 2018-11-19   2.211547  -1.031103   0.961524  -0.449906   0.062056 -10.0
# 2018-11-20  -0.916594   0.817857   1.704408   0.754580  -0.875199 -10.0
# 2018-11-21   1.795535   2.057391   0.640289  -0.212212  -0.646072 -10.0
# 2018-11-22  -0.412105  -0.858991   0.126454  -1.929453  -0.290766 -10.0
# 2018-11-23   1.096568   0.229744   1.275525  -1.174126   0.036696 -10.0
# 2018-11-24   0.067544   0.494046   1.003044  -0.252660   1.193120 -10.0
# 2018-12-01 -10.000000 -10.000000 -10.000000 -10.000000 -10.000000 -10.0

# %%
df = df.drop(pd.Timestamp('20181201'))
df
# Out:
#                    A         B         C         D         Z   X
# 2018-11-15  0.515823  0.077561 -0.158033 -0.572005  1.500157 NaN
# 2018-11-16  0.444033  2.329084  0.192314  0.454020 -1.065538 NaN
# 2018-11-17 -0.325505 -1.468963  1.134555  1.783722 -0.116841 NaN
# 2018-11-18 -0.790104 -0.837978 -0.340629  2.757331 -0.866775 NaN
# 2018-11-19  2.211547 -1.031103  0.961524 -0.449906  0.062056 NaN
# 2018-11-20 -0.916594  0.817857  1.704408  0.754580 -0.875199 NaN
# 2018-11-21  1.795535  2.057391  0.640289 -0.212212 -0.646072 NaN
# 2018-11-22 -0.412105 -0.858991  0.126454 -1.929453 -0.290766 NaN
# 2018-11-23  1.096568  0.229744  1.275525 -1.174126  0.036696 NaN
# 2018-11-24  0.067544  0.494046  1.003044 -0.252660  1.193120 NaN

# %%
# zmiana wybranych wartości
# wyłączenie ostrzeżenia: pd.options.mode.chained_assignment = None
df.loc[df['C'] > 0.5, 'X'] = 30.0
df
# Out:
#                    A         B         C         D         Z     X
# 2018-11-15  0.515823  0.077561 -0.158033 -0.572005  1.500157   NaN
# 2018-11-16  0.444033  2.329084  0.192314  0.454020 -1.065538   NaN
# 2018-11-17 -0.325505 -1.468963  1.134555  1.783722 -0.116841  30.0
# 2018-11-18 -0.790104 -0.837978 -0.340629  2.757331 -0.866775   NaN
# 2018-11-19  2.211547 -1.031103  0.961524 -0.449906  0.062056  30.0
# 2018-11-20 -0.916594  0.817857  1.704408  0.754580 -0.875199  30.0
# 2018-11-21  1.795535  2.057391  0.640289 -0.212212 -0.646072  30.0
# 2018-11-22 -0.412105 -0.858991  0.126454 -1.929453 -0.290766   NaN
# 2018-11-23  1.096568  0.229744  1.275525 -1.174126  0.036696  30.0
# 2018-11-24  0.067544  0.494046  1.003044 -0.252660  1.193120  30.0

# %%
# podstawowe informacje statystyczne

df.describe()
# Out:
#                A          B          C          D          Z     X
# count  10.000000  10.000000  10.000000  10.000000  10.000000   6.0
# mean    0.368674   0.180865   0.653945   0.115929  -0.106916  30.0
# std     1.062813   1.289411   0.673079   1.381042   0.864943   0.0
# min    -0.916594  -1.468963  -0.340629  -1.929453  -1.065538  30.0
# 25%    -0.390455  -0.853738   0.142919  -0.541480  -0.811599  30.0
# 50%     0.255788   0.153653   0.800906  -0.232436  -0.203803  30.0
# 75%     0.951382   0.736904   1.101677   0.679440   0.055716  30.0
# max     2.211547   2.329084   1.704408   2.757331   1.500157  30.0

# %%
# DataFrame można tworzyć na różne sposoby

df2 = pd.DataFrame({ 'A' : 1.,
                     'B' : pd.Timestamp('20130102'),
                     'C' : pd.Series(1, index=list(range(4)), dtype='float32'),
                     'D' : np.array([3] * 4, dtype='int32'),
                     'E' : pd.Categorical(["test","train","test","train"]),
                     'F' : np.random.randint(0, 200000, 4),
                     'G' : np.random.rand(4),
                     'H' : 'foo' })
df2
# Out:
#      A          B    C  D      E       F         G    H
# 0  1.0 2013-01-02  1.0  3   test  171712  0.408598  foo
# 1  1.0 2013-01-02  1.0  3  train  179192  0.075964  foo
# 2  1.0 2013-01-02  1.0  3   test   57753  0.694780  foo
# 3  1.0 2013-01-02  1.0  3  train  158850  0.013389  foo

# %% [markdown]
# Zobacz również [dokumentację](http://pandas.pydata.org/pandas-docs/stable/index.html) oraz [Pandas Cheat Sheet](https://github.com/pandas-dev/pandas/blob/master/doc/cheatsheet/Pandas_Cheat_Sheet.pdf)

# %% [markdown]
# ### Zadanie
#
# Utwórz DataFrame `samochody` z tysiącem losowych danych:
# - `przebieg` z przedziału [0, 200 000]
# - `spalanie` z przedziału [2, 20]
#
# Dodaj kolumnę `marka`:
# - jeżeli samochód ma spalanie [0, 8] marka to VW
# - jeżeli samochód ma spalanie [8, 12] marka to Ford
# - jeżeli samochód ma spalanie 13 i więcej, marka to UAZ
#
# Dodaj kolumnę `pochodzenie`:
# - jeżeli przebieg poniżej 100 km, pochodzenie `new`
# - jeżeli przebieg powyżej 100 km, pochodzenie `PL`
# - jeżeli przebieg powyżej 100 000 km, pochodzenie `DE`
# - zapisz dane do pliku
#
# Przeanalizuj dane statystycznie:
# - pogrupuj dane po marce i po pochodzeniu (wskazówka: użyj `groupby(['marka', 'pochodzenie'])` i wskaż wybraną funkcję statystyczną (np. średnią)
# - narysuj wykres przeanalizowanych danych (wskazówka: użyj wykresu typu `bar`, wskaż drugą oś y `secondary_y=['przebieg']`)
# - sprawdź liczność grup i narysuj wykres
# - wykonaj analizę statystyczną

# %%
#df = pd.DataFrame(np.random.randn(8,4), index=pd.date_range('20181115', periods=8), columns=list('ABCD'))

#df2 = pd.DataFrame({ 'A' : 1.,
#                     'B' : pd.Timestamp('20130102'),
#                     'C' : pd.Series(1, index=list(range(4)), dtype='float32'),
#                     'D' : np.array([3] * 4, dtype='int32'),
#                     'E' : pd.Categorical(["test","train","test","train"]),
#                     'F' : np.random.randint(0, 200000, 4),
#                     'G' : np.random.rand(4),
#                     'H' : 'foo' })

mf = pd.DataFrame({'Przebieg' : np.random.randint(0, 200000, 1000),
                   'Spalanie' : abs(np.random.rand(1000))*18+2})

# zmiana wybranych wartości
# wyłączenie ostrzeżenia: pd.options.mode.chained_assignment = None
#df.loc[df['C'] > 0.5, 'X'] = 30.0
#df

mf.loc[mf.Spalanie <= 8.0, 'Marka'] = 'VW'
mf.loc[mf.Spalanie > 8.0, 'Marka'] = 'Ford'
mf.loc[mf.Spalanie > 12.0, 'Marka'] = 'UAZ'

mf.loc[mf.Przebieg <= 0, 'Pochodzenie'] = 'new'
mf.loc[mf.Przebieg > 100, 'Pochodzenie'] = 'PL'
mf.loc[mf.Przebieg > 100000, 'Pochodzenie'] = 'DE'

mf.head(10)

m = mf.groupby(['Marka', 'Pochodzenie']).mean()
print(m)
m.plot.bar(secondary_y=['Przebieg'])
# Out:
#                         Przebieg   Spalanie
# Marka Pochodzenie
# Ford  DE           148960.480000   9.850856
#       PL            54317.067227  10.207770
# UAZ   DE           149169.518182  16.078838
#       PL            49451.954751  15.922770
# VW    DE           152938.258741   4.849823
#       PL            47527.040698   4.973327

# %%
m = mf.groupby(['Marka', 'Pochodzenie']).count()
print(m)
m = m.drop('Spalanie', axis=1)
m.rename(index=str, columns={"Przebieg:": "Mileage"})
print(m)
#m.plot.bar
# Out:
#                    Przebieg  Spalanie
# Marka Pochodzenie
# Ford  DE                125       125
#       PL                119       119
# UAZ   DE                220       220
#       PL                221       221
# VW    DE                143       143
#       PL                172       172
#                    Przebieg
# Marka Pochodzenie
# Ford  DE                125
#       PL                119
# UAZ   DE                220
#       PL                221
# VW    DE                143
#       PL                172
